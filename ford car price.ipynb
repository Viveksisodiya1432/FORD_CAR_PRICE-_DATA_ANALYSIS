# %%
# %pip install pandas



import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_theme(color_codes=True)
import warnings
warnings.filterwarnings('ignore')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\vivek\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
df=pd.read_csv("archive (3).zip")

# %%
df
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1        Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2        Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3       Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4       Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...        ...   ...    ...          ...      ...      ...  ...   ...
# 17961    B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962    B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963    Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964       KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965    Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...

# %%
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
df.select_dtypes(include='object').nunique()
# Out:
# model           24
# transmission     3
# fuelType         5
# dtype: int64

# %%
df['model'].unique()
# Out:
# array([' Fiesta', ' Focus', ' Puma', ' Kuga', ' EcoSport', ' C-MAX',
#        ' Mondeo', ' Ka+', ' Tourneo Custom', ' S-MAX', ' B-MAX', ' Edge',
#        ' Tourneo Connect', ' Grand C-MAX', ' KA', ' Galaxy', ' Mustang',
#        ' Grand Tourneo Connect', ' Fusion', ' Ranger', ' Streetka',
#        ' Escort', ' Transit Tourneo', 'Focus'], dtype=object)

# %%
df.shape
# Out:
# (17966, 9)

# %%
plt.figure(figsize=(10,5))
df['model'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='model'>

# %%
cat_vars = ['model' , 'transmission' , 'fueltype']

fig,axs = plt.subplots(nrows=1 ,ncols=3 ,figsize=(20,10))
axs = axs.ravel()

for i, var in enumerate(cat_vars):
    sns.barplot(x=var ,y='price',data=df, ax=axs[i],estimator=np.mean)
    axs[i].set_xticklabels(axs[i].get_xticklabels(),rotation=90)

fig.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 7
#       4 axs = axs.ravel()
#       6 for i, var in enumerate(cat_vars):
# ----> 7     sns.barplot(x=var ,y='price',data=df, ax=axs[i],estimator=np.mean)
#       8     axs[i].set_xticklabels(axs[i].get_xticklabels(),rotation=90)
#      10 fig.tight_layout()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
# ...

# %%
cat_vars = [ 'transmission' , 'fuelType']

fig,axs = plt.subplots(nrows=1 ,ncols=3 ,figsize=(15,15))

for i, var in enumerate(cat_vars):
    if i < len(axs.flat):
        cat_counts = df[var].value_counts()

    axs.flat[i].pie(cat_counts,labels=cat_counts.index,autopct='%1.1f%%',startangle=90)

    axs.flat[i].set_title(f'{var} distribution')    

fig.tight_layout()

plt.show()

# %%
num_vars = ['mileage', 'tax' , 'mpg' , 'engineSize']

fig ,axs = plt.subplots(nrows=2,ncols=2, figsize=(20,10))
axs = axs.flatten()

for i, var in enumerate(num_vars):
    sns.boxplot(x=var, data=df,ax=axs[i])

fig.tight_layout()

plt.show()

# %%
num_vars = ['mileage', 'tax' , 'mpg' , 'engineSize']

fig ,axs = plt.subplots(nrows=2,ncols=2, figsize=(20,10))
axs = axs.flatten()

for i, var in enumerate(num_vars):
    sns.violinplot(x=var, data=df,ax=axs[i])

fig.tight_layout()

plt.show()

# %%
num_vars = ['mileage', 'tax' , 'mpg' , 'engineSize']

fig ,axs = plt.subplots(nrows=2,ncols=2, figsize=(20,10))
axs = axs.flatten()

for i, var in enumerate(num_vars):
    sns.scatterplot(x=var,y='price',hue='transmission' ,data=df,ax=axs[i])

fig.tight_layout()

plt.show()

# %%
num_vars = ['mileage', 'tax' , 'mpg' , 'engineSize']

fig ,axs = plt.subplots(nrows=2,ncols=2, figsize=(20,10))
axs = axs.flatten()

for i, var in enumerate(num_vars):
    sns.scatterplot(x=var,y='price',hue='fuelType' ,data=df,ax=axs[i])

fig.tight_layout()

plt.show()

# %%
sns.set_style('darkgrid')
sns.set_paletten('set')

sns.lineplot(x='year',y='price',hue='model',data=df,ci=None,estimator='mean',alpha=0.7)

plt.title('price by year sold and cars type')
plt.xlabel('year')
plt.ylabel('price')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 2
#       1 sns.set_style('darkgrid')
# ----> 2 sns.set_paletten('set')
#       4 sns.lineplot(x='year',y='price',hue='model',data=df,ci=None,estimator='mean',alpha=0.7)
#       6 plt.title('price by year sold and cars type')
#
# AttributeError: module 'seaborn' has no attribute 'set_paletten'

# %%
sns.set_style('darkgrid')
sns.set_palette('set2')

sns.lineplot(x='year',y='price',hue='transmission',data=df,ci=None,estimator='mean',alpha=0.7)

plt.title('price by year sold and cars type')
plt.xlabel('year')
plt.ylabel('price')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\seaborn\palettes.py:235, in color_palette(palette, n_colors, desat, as_cmap)
#     233 try:
#     234     # Perhaps a named matplotlib colormap?
# --> 235     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236 except (ValueError, KeyError):  # Error class changed in mpl36
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\seaborn\palettes.py:406, in mpl_palette(name, n_colors, as_cmap)
#     405 else:
# --> 406     cmap = get_colormap(name)
#     408 if name in MPL_QUAL_PALS:
#
# ...

# %%
df.shape
# Out:
# (17966, 9)

# %%
df=df[df['year'] <=2023]
df.shape
# Out:
# (17965, 9)

# %%
check_missing = df.isnull().sum() * 100/ df.shape[0]
check_missing[check_missing >0].sort_values(ascending=False)
# Out:
# Series([], dtype: float64)

# %%
for col in df.select_dtypes(include=['object']).columns:
    print(f"{col}:{df[col].unique()}")
# Out:
# model:[' Fiesta' ' Focus' ' Puma' ' Kuga' ' EcoSport' ' C-MAX' ' Mondeo' ' Ka+'
#  ' Tourneo Custom' ' S-MAX' ' B-MAX' ' Edge' ' Tourneo Connect'
#  ' Grand C-MAX' ' KA' ' Galaxy' ' Mustang' ' Grand Tourneo Connect'
#  ' Fusion' ' Ranger' ' Streetka' ' Escort' ' Transit Tourneo' 'Focus']
# transmission:['Automatic' 'Manual' 'Semi-Auto']
# fuelType:['Petrol' 'Diesel' 'Hybrid' 'Electric' 'Other']

# %%
plt.figure(figsize=(20,16))
sns.heatmap(df.corr(),fmt='%.2g',annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 plt.figure(figsize=(20,16))
# ----> 2 sns.heatmap(df.corr(),fmt='%.2g',annot=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
# ...

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17961    False
# 17962    False
# 17963    False
# 17964    False
# 17965    False
# Length: 17965, dtype: bool

# %%
df.drop_duplicates()
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1        Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2        Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3       Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4       Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...        ...   ...    ...          ...      ...      ...  ...   ...
# 17961    B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962    B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963    Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964       KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965    Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...

# %%
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
df.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  17965.000000  17965.000000   17965.000000  17965.000000  17965.000000
# mean    2016.864069  12279.856833   23360.858447    113.324353     57.907821
# std        2.024978   4741.279186   19471.182902     62.010410     10.125350
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000    9987.000000     30.000000     52.300000
# 50%     2017.000000  11291.000000   18242.000000    145.000000     58.900000
# 75%     2018.000000  15299.000000   31048.000000    145.000000     65.700000
# max     2020.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17965.000000
# mean       1.350804
# std        0.432379
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17965 entries, 0 to 17965
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         17965 non-null  object
#  1   year          17965 non-null  int64
#  2   price         17965 non-null  int64
#  3   transmission  17965 non-null  object
#  4   mileage       17965 non-null  int64
#  5   fuelType      17965 non-null  object
#  6   tax           17965 non-null  int64
#  7   mpg           17965 non-null  float64
#  8   engineSize    17965 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 1.4+ MB

# %%
df.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
df.count()
# Out:
# model           17965
# year            17965
# price           17965
# transmission    17965
# mileage         17965
# fuelType        17965
# tax             17965
# mpg             17965
# engineSize      17965
# dtype: int64

# %%
df['model']
# Out:
# 0         Fiesta
# 1          Focus
# 2          Focus
# 3         Fiesta
# 4         Fiesta
#           ...
# 17961      B-MAX
# 17962      B-MAX
# 17963      Focus
# 17964         KA
# 17965      Focus
# Name: model, Length: 17966, dtype: object

# %%
df.columns
# Out:
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize'],
#       dtype='object')

# %%
df["engineSize"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='engineSize'>

# %%
df
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1        Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2        Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3       Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4       Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...        ...   ...    ...          ...      ...      ...  ...   ...
# 17961    B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962    B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963    Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964       KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965    Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...

# %%
df['year'].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='year'>

# %%
df['year'].head(7000).value_counts().plot(kind='pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df.shape
# Out:
# (17966, 9)

# %%
df['fuelType'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df.describe().transpose
# Out:
# <bound method DataFrame.transpose of                year         price        mileage           tax           mpg  \
# count  17966.000000  17966.000000   17966.000000  17966.000000  17966.000000
# mean    2016.866470  12279.534844   23362.608761    113.329456     57.906980
# std        2.050336   4741.343657   19472.054349     62.012456     10.125696
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000    9987.000000     30.000000     52.300000
# 50%     2017.000000  11291.000000   18242.500000    145.000000     58.900000
# 75%     2018.000000  15299.000000   31060.000000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17966.000000
# mean       1.350807
# std        0.432367
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000  >

# %%
df.duplicated().sum()
# Out:
# np.int64(154)

# %%
df.dropna(inplace= True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.drop_duplicates()
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1        Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2        Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3       Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4       Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...        ...   ...    ...          ...      ...      ...  ...   ...
# 17961    B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962    B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963    Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964       KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965    Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...

# %%
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
plt.hist(df['model'])
# Out:
# (array([1.1225e+04, 3.3680e+03, 1.0690e+03, 8.9600e+02, 5.6300e+02,
#         2.8000e+02, 4.8400e+02, 7.5000e+01, 3.0000e+00, 3.0000e+00]),
#  array([ 0. ,  2.3,  4.6,  6.9,  9.2, 11.5, 13.8, 16.1, 18.4, 20.7, 23. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(df['mpg'].head(50))

# %%
df.isnull().mean()*100
# Out:
# model           0.0
# year            0.0
# price           0.0
# transmission    0.0
# mileage         0.0
# fuelType        0.0
# tax             0.0
# mpg             0.0
# engineSize      0.0
# dtype: float64

# %%
df['tax'].skew()
# Out:
# np.float64(-0.564082137792832)

# %%
sns.displot(df['mileage'])

# %%
sns.boxplot(df['fuelType'])
# Out:
# <Axes: ylabel='fuelType'>

# %%
plt.plot(df.model.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.plot(df.model.head())
#
# NameError: name 'plt' is not defined

# %%
df['engineSize'].value_counts().plot(kind='line')
plt.title('Tesla stock clossing price', fontsize=30)
plt.show()

# %%
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
sns.displot(df.transmission)
